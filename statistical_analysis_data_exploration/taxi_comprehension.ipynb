# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###  Problem - I
# Which of the following is the least affected by the distance traveled by a taxi on a particular trip?

# %%
taxis_df = pd.read_csv('taxis.csv')

# %%
taxis_corr = taxis_df.corr(numeric_only=True)

# %%
ax = sns.heatmap(data=taxis_corr, annot=True, linewidths=1, center=0, vmax=1, vmin=-1)
