# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
tips_df = sns.load_dataset("tips")

# %%
ax = sns.histplot(data=tips_df, x="total_bill", y="tip")
