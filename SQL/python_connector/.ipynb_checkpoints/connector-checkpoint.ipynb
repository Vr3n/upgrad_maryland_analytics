# %% [markdown]
# Installing Mysql connector.

# %%
# !pip install mysql-connector-python
# Out:
# ...
#   Obtaining dependency information for mysql-connector-python from https://files.pythonhosted.org/packages/9d/1b/a7b17532d6c7972e9173d9cc6fad5f94b949bcaaafa744f4e68a255ebd37/mysql_connector_python-8.1.0-cp310-cp310-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#      -------- ----------------------------- 112.6/527.0 kB 2.2 MB/s eta 0:00:01
#      ---------------- --------------------- 225.3/527.0 kB 2.3 MB/s eta 0:00:01
#      ------------------------ ------------- 337.9/527.0 kB 2.3 MB/s eta 0:00:01
#      ------------------------------ ------- 419.8/527.0 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------  522.2/527.0 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 527.0/527.0 kB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.9 MB 2.4 MB/s eta 0:00:05
# ...

# %%
import mysql.connector
import pandas as pd

# %%
# connect the database.
conn = mysql.connector.connect(
    host='127.0.0.1',
    database='smithazon',
    user='Vr3n',
    password='<!Sc3venZovski>'
)

# %%
df_customers = pd.read_sql('SELECT * FROM customer', conn, index_col='customer_num')
# Out:
# C:\Users\Vr3n\AppData\Local\Temp\ipykernel_9344\2200459969.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_customers = pd.read_sql('SELECT * FROM customer', conn, index_col='customer_num')

# %%
df_customers
# Out:
#                   customer_name               street             city state  \
# customer_num
# 1001          Traders' Emporium  4281 Farm Meadow Dr        Ehrenberg    AZ
# 1002             Leny and Trond       1952 Confer Dr          Seattle    WA
# 1003                   Shop Cog    2709 Hillcrest Rd          Tukwila    WA
# 1004                 Store Folk     10245 Big Elm St           Lenexa    MO
# 1005                  retail.ly      1115 Bedford St       West Haven    CT
# 1006             Stuff & Things     534 Longview Ave            Bronx    NY
# 1007                    Unboxed    3185 Alexander Dr           Denton    TX
# 1008                Shop Nation    3570 Stratford Ct        Charlotte    NC
# 1009               Retail Creed     3093 Margaret St          Houston    TX
# 1010             Merchant Aisle      4832 Finwood Rd          Neptune    NJ
# 1011               Smith & Sons     2586 Rinehart Rd  Fort Lauderdale    FL
#
# ...

# %%
df_customer_rep = pd.read_sql(
    """
    SELECT c.customer_num, c.customer_name, r.first_name, r.last_name
    FROM customer c
        INNER JOIN representative r ON r.rep_num = c.rep_num;
    """,
    conn
)
